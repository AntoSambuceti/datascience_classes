# %% [markdown]
# # EDA Análisis exploratorio de datos

# %% [markdown]
# ## Importación de librerías

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Importación de librerías

# %%
data = pd.read_csv("sysarmy.csv")

# %%
data.isna().sum()
# Out:
# estoy_trabajando_en                                                                        0
# donde_estas_trabajando                                                                     0
# dedicacion                                                                                 0
# tipo_de_contrato                                                                           0
# ultimo_salario_mensual_o_retiro_bruto_en_tu_moneda_local                                   0
# ultimo_salario_mensual_o_retiro_neto_en_tu_moneda_local                                  210
# pagos_en_dolares                                                                        3639
# si_tu_sueldo_esta_dolarizado_cual_fue_el_ultimo_valor_del_dolar_que_tomaron             4305
# recibis_algun_tipo_de_bono                                                                 0
# a_que_esta_atado_el_bono                                                                   0
# ...

# %%
data.shape
# Out:
# (5422, 47)

# %%
empleos_data = ['BI Analyst / Data Analyst','Data Engineer','Machine Learning Engineer',
                'Business Analyst','Business Analyst / Product Owner','Lead Data Science',
                'Responsable de Data Engineer & Data Governance','Data Governance',
                'BI Trainee', 'Head of data & ai','Head de Data','Machine learning engineer']

# %%
data['trabajo_de'].unique()
# Out:
# array(['Scrum Master', 'Developer', 'Technical Support',
#        'Manager / Director', 'SysAdmin / DevOps / SRE', 'Networking',
#        'Technical Leader', 'HelpDesk', 'Data Scientist', 'Infosec',
#        'QA / Tester', 'Sales / Pre-Sales', 'Data Engineer', 'Architect',
#        'BI Analyst / Data Analyst', 'Recruiter / HR', 'Middleware',
#        'Functional Analyst', 'Consultant', 'UX', 'Engineer',
#        'Machine Learning Engineer', 'DBA', 'AI trainer (programming)',
#        'Cloud architect', 'Designer', 'Jefe Sistemas - Comunicaciones',
#        'Moodle Administrator', 'Business Analyst', 'Marketing',
#        'Web Design and Maintenance', 'Finance', 'Web Master',
#        'Game Designer', 'VP / C-Level', 'Product Support Engineer y DBA',
#        'Technical Writer', 'Docente', 'Performance test engineer',
#        'Data center', 'Product Designer', 'System Engineer',
#        'CiberSecurity', 'Business Analyst / Product Owner', 'RH',
# ...

# %%
data[data['trabajo_de'].isin(empleos_data)]
# Out:
#      estoy_trabajando_en           donde_estas_trabajando dedicacion  \
# 38             Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 52             Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 54             Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 98             Argentina                          Córdoba  Full-Time
# 109            Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# ...                  ...                              ...        ...
# 5344           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 5351           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 5373           Argentina  Ciudad Autónoma de Buenos Aires  Full-Time
# 5382           Argentina                         Misiones  Full-Time
# 5404           Argentina                         Santa Fe  Full-Time
#
#                                        tipo_de_contrato  \
# 38    Tercerizado (trabajo a través de consultora o ...
# ...

# %%
data = pd.read_csv("loan.csv")

# %%
data.age.describe()
# Out:
# count    61.000000
# mean     37.081967
# std       8.424755
# min      24.000000
# 25%      30.000000
# 50%      36.000000
# 75%      43.000000
# max      55.000000
# Name: age, dtype: float64

# %%
data.columns
# Out:
# Index(['age', 'gender', 'occupation', 'education_level', 'marital_status',
#        'income', 'credit_score', 'loan_status'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# age                0
# gender             0
# occupation         0
# education_level    0
# marital_status     0
# income             0
# credit_score       0
# loan_status        0
# dtype: int64

# %%
data.occupation.value_counts()
# Out:
# Engineer        5
# Analyst         2
# Chef            2
# Writer          2
# Banker          2
# Receptionist    2
# Teacher         2
# Professor       2
# Designer        2
# Marketing       2
# Salesman        2
# Architect       2
# Consultant      2
# Doctor          2
# IT              2
# Artist          2
# Lawyer          2
# Nurse           2
# Accountant      2
# Manager         2
# Photographer    1
# Server          1
# Psychologist    1
# Software        1
# Musician        1
# Dentist         1
# Programmer      1
# Editor          1
# Pilot           1
# Realtor         1
# Electrician     1
# HR              1
# Sales           1
# Veterinarian    1
# Researcher      1
# Pharmacist      1
# Student         1
# Stylist         1
# Name: occupation, dtype: int64

# %%
data.age.unique()
# Out:
# array([32, 45, 28, 51, 36, 24, 42, 29, 37, 48, 55, 31, 26, 39, 44, 27, 34,
#        41, 30, 53, 38, 25, 46, 33, 40, 35, 43, 49, 54, 47, 52, 50])
